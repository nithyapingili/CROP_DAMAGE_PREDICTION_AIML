# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
train = pd.read_csv('/content/train (1).csv')
print(train)
train.info()
# Out:
#               ID  Estimated_Insects_Count  Crop_Type  Soil_Type  \
# 0      F00000001                      188          1          0
# 1      F00000003                      209          1          0
# 2      F00000004                      257          1          0
# 3      F00000005                      257          1          1
# 4      F00000006                      342          1          0
# ...          ...                      ...        ...        ...
# 88853  F00155935                     3337          1          0
# 88854  F00155938                     3516          1          0
# 88855  F00155939                     3516          1          0
# 88856  F00155942                     3702          1          0
# 88857  F00155945                     3895          1          0
#
#        Pesticide_Use_Category  Number_Doses_Week  Number_Weeks_Used  \
# 0                           1                  0                0.0
# ...

# %%
train.shape
# Out:
# (88858, 10)

# %%
train.nunique()
# Out:
# ID                         88858
# Estimated_Insects_Count       71
# Crop_Type                      2
# Soil_Type                      2
# Pesticide_Use_Category         3
# Number_Doses_Week             20
# Number_Weeks_Used             64
# Number_Weeks_Quit             51
# Season                         3
# Crop_Damage                    3
# dtype: int64

# %%
train.isnull().sum()
# Out:
# ID                            0
# Estimated_Insects_Count       0
# Crop_Type                     0
# Soil_Type                     0
# Pesticide_Use_Category        0
# Number_Doses_Week             0
# Number_Weeks_Used          9000
# Number_Weeks_Quit             0
# Season                        0
# Crop_Damage                   0
# dtype: int64

# %%
train['Number_Weeks_Used'].fillna(train['Number_Weeks_Used'].mean(),inplace=True)

# %%
train.drop(columns=["ID"],axis=1,inplace=True)
train.dtypes
# Out:
# Estimated_Insects_Count      int64
# Crop_Type                    int64
# Soil_Type                    int64
# Pesticide_Use_Category       int64
# Number_Doses_Week            int64
# Number_Weeks_Used          float64
# Number_Weeks_Quit            int64
# Season                       int64
# Crop_Damage                  int64
# dtype: object

# %%
print(train.columns)
print(train.shape)
# Out:
# Index(['Estimated_Insects_Count', 'Crop_Type', 'Soil_Type',
#        'Pesticide_Use_Category', 'Number_Doses_Week', 'Number_Weeks_Used',
#        'Number_Weeks_Quit', 'Season', 'Crop_Damage'],
#       dtype='object')
# (88858, 9)

# %%
X=train.drop(columns=['Crop_Damage'])
Y=train[["Crop_Damage"]]

# %%
print(X)
# Out:
#        Estimated_Insects_Count  Crop_Type  Soil_Type  Pesticide_Use_Category  \
# 0                          188          1          0                       1
# 1                          209          1          0                       1
# 2                          257          1          0                       1
# 3                          257          1          1                       1
# 4                          342          1          0                       1
# ...                        ...        ...        ...                     ...
# 88853                     3337          1          0                       2
# 88854                     3516          1          0                       2
# 88855                     3516          1          0                       2
# 88856                     3702          1          0                       2
# 88857                     3895          1          0                       2
#
# ...

# %%
print(Y)
# Out:
#        Crop_Damage
# 0                0
# 1                1
# 2                1
# 3                1
# 4                1
# ...            ...
# 88853            0
# 88854            0
# 88855            0
# 88856            0
# 88857            0
#
# [88858 rows x 1 columns]

# %%
Y.value_counts()
# Out:
# Crop_Damage
# 0              74238
# 1              12307
# 2               2313
# dtype: int64

# %%
a = train['Estimated_Insects_Count'].values
b=train['Crop_Damage'].values
plt.plot(a,b)
plt.title('Estimated_Insects_Count VS CROP DAMAGE')
plt.xlabel("Estimated_Insects_Count")
plt.ylabel('CROP DAMAGE')
plt.show()

# %%
a = train['Soil_Type'].values
b=train['Crop_Damage'].values
plt.plot(a,b)
plt.title('Soil Type VS CROP DAMAGE')
plt.xlabel("Soil_Type")
plt.ylabel('CROP DAMAGE')
plt.show()

# %%
a = train['Crop_Type'].values
b=train['Crop_Damage'].values
plt.plot(a,b)
plt.title('Crop_Type  VS CROP DAMAGE')
plt.xlabel("Crop_Type")
plt.ylabel('CROP DAMAGE')
plt.show()

# %%
a = train['Pesticide_Use_Category'].values
b=train['Crop_Damage'].values
plt.plot(a,b)
plt.title('Pesticide_Use_Category VS CROP DAMAGE')
plt.xlabel("Pesticide_Use_Category")
plt.ylabel('CROP DAMAGE')
plt.show()

# %%
a = train['Number_Doses_Week'].values
b=train['Crop_Damage'].values
plt.plot(a,b)
plt.title('Number_Doses_Week VS CROP DAMAGE')
plt.xlabel("Number_Doses_Week")
plt.ylabel('CROP DAMAGE')
plt.show()

# %%
a = train['Number_Weeks_Used'].values
b=train['Crop_Damage'].values
plt.plot(a,b)
plt.title('Number_Weeks_Used VS CROP DAMAGE')
plt.xlabel("Number_Weeks_Used")
plt.ylabel('CROP DAMAGE')
plt.show()

# %%
a = train['Number_Weeks_Quit'].values
b=train['Crop_Damage'].values
plt.plot(a,b)
plt.title('Number_Weeks_Quit VS CROP DAMAGE')
plt.xlabel("Number_Weeks_Quit")
plt.ylabel('CROP DAMAGE')
plt.show()

# %%
a = train['Season'].values
b=train['Crop_Damage'].values
plt.plot(a,b)
plt.title('Season VS CROP DAMAGE')
plt.xlabel("Season")
plt.ylabel('CROP DAMAGE')
plt.show()

# %%
train.plot(kind="box",subplots=True,layout=(5,5),figsize=(15,15))
# Out:
# Estimated_Insects_Count       AxesSubplot(0.125,0.749828;0.133621x0.130172)
# Crop_Type                  AxesSubplot(0.285345,0.749828;0.133621x0.130172)
# Soil_Type                   AxesSubplot(0.44569,0.749828;0.133621x0.130172)
# Pesticide_Use_Category     AxesSubplot(0.606034,0.749828;0.133621x0.130172)
# Number_Doses_Week          AxesSubplot(0.766379,0.749828;0.133621x0.130172)
# Number_Weeks_Used             AxesSubplot(0.125,0.593621;0.133621x0.130172)
# Number_Weeks_Quit          AxesSubplot(0.285345,0.593621;0.133621x0.130172)
# Season                      AxesSubplot(0.44569,0.593621;0.133621x0.130172)
# Crop_Damage                AxesSubplot(0.606034,0.593621;0.133621x0.130172)
# dtype: object

# %%
import seaborn as sn
sn.boxplot(data=train,x='Estimated_Insects_Count')
# Out:
# <AxesSubplot:xlabel='Estimated_Insects_Count'>

# %%
sn.boxplot(data=train,x='Crop_Type')
# Out:
# <AxesSubplot:xlabel='Crop_Type'>

# %%
sn.boxplot(data=train,x='Soil_Type')
# Out:
# <AxesSubplot:xlabel='Soil_Type'>

# %%
sn.boxplot(data=train,x='Pesticide_Use_Category')
# Out:
# <AxesSubplot:xlabel='Pesticide_Use_Category'>

# %%
sn.boxplot(data=train,x='Number_Doses_Week')
# Out:
# <AxesSubplot:xlabel='Number_Doses_Week'>

# %%
sn.boxplot(data=train,x='Number_Weeks_Used')
# Out:
# <AxesSubplot:xlabel='Number_Weeks_Used'>

# %%
sn.boxplot(data=train,x='Number_Weeks_Quit')
# Out:
# <AxesSubplot:xlabel='Number_Weeks_Quit'>

# %%
sn.boxplot(data=train,x='Season')
# Out:
# <AxesSubplot:xlabel='Season'>

# %%
sn.boxplot(data=train,x='Crop_Damage')
# Out:
# <AxesSubplot:xlabel='Crop_Damage'>

# %%
import seaborn as sn
cov_matrix = pd.DataFrame.cov(train)
sn.heatmap(cov_matrix, annot=True, fmt='g')
plt.show()

# %%
import seaborn as sns
sns.heatmap(train.corr(),annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
import seaborn as s
plt.figure(figsize=(12,5))
s.catplot(x='Crop_Damage', data=train, palette="hls",kind='count')

# %%
train.groupby('Crop_Damage').nunique().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Crop_Damage'>

# %%
X=train.drop(columns=['Crop_Damage'])
Y=train[["Crop_Damage"]]

# %%
from sklearn.preprocessing import StandardScaler 
sc = StandardScaler()
x = sc.fit_transform(X)
X=pd.DataFrame(x,columns=X.columns)

# %% [markdown]
# LOGISTIC REGRESSION

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25,stratify=Y, random_state=2)
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
model = LogisticRegression()
model.fit(X_train, Y_train.values.reshape(-1,))
# Out:
# LogisticRegression()

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print('Accuracy score of the training data : ', training_data_accuracy)
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print('Accuracy score of the test data : ', test_data_accuracy)
# Out:
# Accuracy score of the training data :  0.8333508395480396
# Accuracy score of the test data :  0.8331307674994373

# %%
y_pred=model.predict(X_test)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test,y_pred)
cm
# Out:
# array([[18350,   210,     0],
#        [ 2919,   158,     0],
#        [  538,    40,     0]])

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %% [markdown]
# KNN

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25,stratify=Y, random_state=2)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(X_train)
X_train=scaler.transform(X_train)
X_test=scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier=KNeighborsClassifier(n_neighbors=5)
classifier.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88858 entries, 0 to 88857
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Estimated_Insects_Count  88858 non-null  int64
#  1   Crop_Type                88858 non-null  int64
#  2   Soil_Type                88858 non-null  int64
#  3   Pesticide_Use_Category   88858 non-null  int64
#  4   Number_Doses_Week        88858 non-null  int64
#  5   Number_Weeks_Used        88858 non-null  float64
#  6   Number_Weeks_Quit        88858 non-null  int64
#  7   Season                   88858 non-null  int64
#  8   Crop_Damage              88858 non-null  int64
# dtypes: float64(1), int64(8)
# memory usage: 6.1 MB

# %%
from sklearn.metrics import classification_report
y_pred=classifier.predict(X_test)
print(classification_report(Y_test,y_pred))
print("accuracy score in knn is:",accuracy_score(Y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91     18560
#            1       0.41      0.21      0.28      3077
#            2       0.17      0.02      0.04       578
#
#     accuracy                           0.83     22215
#    macro avg       0.48      0.40      0.41     22215
# weighted avg       0.78      0.83      0.80     22215
#
# accuracy score in knn is: 0.8298897141571011

# %%
print("accuracy score in knn is:",accuracy_score(Y_test,y_pred))
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print('Accuracy score of the test data : ', test_data_accuracy)
# Out:
# accuracy score in knn is: 0.8298897141571011
# Accuracy score of the test data :  0.8331307674994373

# %%
y_pred=model.predict(X_test)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test,y_pred)
cm
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([[18350,   210,     0],
#        [ 2920,   157,     0],
#        [  538,    40,     0]])

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %% [markdown]
# SVM

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.3,random_state=109)

# %%
from sklearn import svm
clf = svm.SVC(kernel='linear') 
clf.fit(X_train, y_train.values.reshape(-1,))
# Out:
# SVC(kernel='linear')

# %%
from sklearn import metrics
y_pred = clf.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8328831870357867

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[22203,     0,     0],
#        [ 3747,     0,     0],
#        [  708,     0,     0]])

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %% [markdown]
# decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25,stratify=Y, random_state=2)
d=DecisionTreeClassifier()
d=d.fit(X_train,Y_train)
Y_pred=d.predict(X_test)
print('accuracy:',metrics.accuracy_score(Y_test,Y_pred))
# Out:
# accuracy: 0.749763673193788

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test,Y_pred)
cm
# Out:
# array([[15786,  2382,   392],
#        [ 2064,   823,   190],
#        [  321,   210,    47]])

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %% [markdown]
# RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from scipy.stats import randint
from sklearn.tree import export_graphviz
from IPython.display import Image
import graphviz
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
rf = RandomForestClassifier()
rf.fit(X_train, Y_train.values.reshape(-1))
y_pred = rf.predict(X_test)
accuracy = accuracy_score(Y_test, y_pred)
print("Accuracy:", accuracy*100)
# Out:
# Accuracy: 82.60747242853927

# %% [markdown]
# AFTER BALANCING THE DATA

# %%
from imblearn.over_sampling import RandomOverSampler
ros=RandomOverSampler(sampling_strategy="not majority")
x_res,y_res=ros.fit_resample(X,Y)

# %%
y_res.value_counts()
# Out:
# Crop_Damage
# 0              74238
# 1              74238
# 2              74238
# dtype: int64

# %%
import seaborn as sns
sns.heatmap(y_res.corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
import seaborn as s
plt.figure(figsize=(12,5))
s.catplot(x='Crop_Damage', data=y_res, palette="hls",kind='count')

# %%
from sklearn.preprocessing import StandardScaler 
sc = StandardScaler()
x = sc.fit_transform(x_res)
x_res=pd.DataFrame(x,columns=x_res.columns)

# %% [markdown]
# LOGISTIC REGRESSION

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
X_train, X_test, Y_train, Y_test = train_test_split(x_res, y_res, test_size = 0.25,stratify=y_res, random_state=2)
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
model = LogisticRegression()
model.fit(X_train, Y_train.values.reshape(-1,))
# Out:
# LogisticRegression()

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print('Accuracy score of the training data : ', training_data_accuracy)
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print('Accuracy score of the test data : ', test_data_accuracy)
# Out:
# Accuracy score of the training data :  0.5170712724878019
# Accuracy score of the test data :  0.519980603099912

# %%
y_pred=model.predict(X_test)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test,y_pred)
cm
# Out:
# array([[12070,  2185,  4305],
#        [ 5556,  3608,  9396],
#        [ 3539,  1746, 13274]])

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %% [markdown]
# KNN

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x_res,y_res, test_size = 0.25,stratify=y_res, random_state=2)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(X_train)
X_train=scaler.transform(X_train)
X_test=scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier=KNeighborsClassifier(n_neighbors=5)
classifier.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
from sklearn.metrics import classification_report
y_pred=classifier.predict(X_test)
print(classification_report(Y_test,y_pred))
print("accuracy score in knn is:",accuracy_score(Y_test,y_pred))
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print('Accuracy score of the test data : ', test_data_accuracy)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.66      0.77     18560
#            1       0.76      0.90      0.82     18560
#            2       0.92      0.99      0.95     18559
#
#     accuracy                           0.85     55679
#    macro avg       0.86      0.85      0.85     55679
# weighted avg       0.86      0.85      0.85     55679
#
# accuracy score in knn is: 0.8535174841502182
# Accuracy score of the test data :  0.5189029975394673

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test,y_pred)
cm
# Out:
# array([[12333,  5315,   912],
#        [ 1026, 16749,   785],
#        [    0,   118, 18441]])

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x_res,y_res, test_size = 0.25,stratify=y_res, random_state=2)

# %%
from sklearn.svm import SVC
clf = SVC() 
clf.fit(X_train, Y_train)

# %%
from sklearn import metrics
y_pred = clf.predict(X_test)
print("Accuracy:",metrics.accuracy_score(Y_test, y_pred))

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test,y_pred)
cm

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')

# %% [markdown]
# DECESION TREE

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
X_train, X_test, Y_train, Y_test = train_test_split(x_res,y_res, test_size = 0.25,stratify=y_res, random_state=2)
d=DecisionTreeClassifier()
d=d.fit(X_train,Y_train.values.reshape(-1,))
Y_pred=d.predict(X_test)
print('accuracy of training data:',metrics.accuracy_score(Y_test,Y_pred))
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print('Accuracy score of the test data : ', test_data_accuracy)
# Out:
# accuracy of training data: 0.9270281434652203
# Accuracy score of the test data :  0.5189029975394673

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test,Y_pred)
cm
# Out:
# array([[15251,  2792,   517],
#        [  152, 17806,   602],
#        [    0,     0, 18559]])

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %% [markdown]
# RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from scipy.stats import randint
from sklearn.tree import export_graphviz
from IPython.display import Image
import graphviz
X_train, X_test, Y_train, Y_test = train_test_split(x_res, y_res, test_size=0.2)
rf = RandomForestClassifier()
rf.fit(X_train, Y_train.values.reshape(-1))
y_pred = rf.predict(X_test)
accuracy = accuracy_score(Y_test, y_pred)
print("Accuracy:", accuracy*100)
# Out:
# Accuracy: 94.83196012841523
